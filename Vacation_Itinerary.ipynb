# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head(60)
# Out:
#     City_ID              City Country  Max Temp      Lat       Lng  \
# 0         2          Bengkulu      ID     74.41  -3.8004  102.2655
# 1         3            Atuona      PF     77.13  -9.8000 -139.0333
# 2         7            Hirara      JP     77.11  24.8000  125.2833
# 3        16           Labuhan      ID     76.60  -6.8844  112.2051
# 4        17   Bambous Virieux      MU     73.65 -20.3428   57.7575
# 5        20   Arraial Do Cabo      BR     76.96 -22.9661  -42.0278
# 6        23              Chuy      UY     70.21 -33.6971  -53.4616
# 7        26           Rikitea      PF     73.22 -23.1203 -134.9692
# 8        34      Puerto Ayora      EC     73.36  -0.7393  -90.3518
# 9        35            Bethel      US     73.49  41.3712  -73.4140
# 10       44    Saint-Philippe      RE     72.99 -21.3585   55.7679
# 11       45            Nabire      ID     75.65  -3.3667  135.4833
# 12       51           Methoni      GR     70.21  36.8197   21.7049
# 13       56            Castro      BR     78.30 -24.7911  -50.0119
# 14       58       Suphan Buri      TH     76.05  14.4742  100.1222
# 15       59              Payo      ID     72.66  -3.7508  103.6372
# 16       73             Bilma      NE     78.22  18.6853   12.9164
# 17       76             Baena      ES     79.43  37.6167   -4.3225
# 18       79           Calella      ES     74.21  41.6180    2.6678
# 19       82            Faanui      PF     76.42 -16.4833 -151.7500
# 20       83             Wewak      PG     79.18  -3.5534  143.6268
# 21       87            Mackay      AU     70.68 -21.1500  149.2000
# 22       93       Chitungwiza      ZW     71.35 -18.0127   31.0756
# 23       94           Gamboma      CG     75.13  -1.8764   15.8644
# 24      110           Peniche      PT     74.08  39.3558   -9.3811
# 25      112        Georgetown      MY     78.73   5.4112  100.3354
# 26      113           Honiara      SB     76.93  -9.4333  159.9500
# 27      114            Songea      TZ     72.75 -10.6833   35.6500
# 28      118            Padang      ID     76.69  -0.9492  100.3543
# 29      124          Souillac      MU     73.78 -20.5167   57.5167
# 30      127             Kapaa      US     77.09  22.0752 -159.3190
# 31      135    Guerrero Negro      MX     72.36  27.9769 -114.0611
# 32      136  Kuala Terengganu      MY     78.75   5.3302  103.1408
# 33      137            Katobu      ID     75.90  -4.9408  122.5276
# 34      139           Kumluca      TR     72.41  36.3703   30.2869
# 35      141           Veraval      IN     78.55  20.9000   70.3667
# 36      142      Ponta Do Sol      PT     74.71  32.6667  -17.1000
# 37      143          Victoria      HK     74.32  22.2855  114.1577
# 38      144             Ambon      ID     77.14  -3.6954  128.1814
# 39      155          Cidreira      BR     72.39 -30.1811  -50.2056
# 40      161              Biak      ID     76.80  -0.9131  122.8766
# 41      162            Dingle      PH     76.08  10.9995  122.6711
# 42      163             Yanam      IN     75.69  16.7333   82.2167
# 43      166         Mahebourg      MU     73.69 -20.4081   57.7000
# 44      174           Isangel      VU     73.26 -19.5500  169.2667
# 45      175            Turayf      SA     70.05  31.6725   38.6637
# 46      176              Sibu      MY     75.51   2.3000  111.8167
# 47      185              Sola      VU     79.30 -13.8833  167.5500
# 48      190        Sao Filipe      CV     78.71  14.8961  -24.4956
# 49      192             Yumbe      UG     70.83   3.4651   31.2469
# 50      193        Sarankhola      BD     71.17  22.3082   89.7897
# 51      195             Kutum      SD     75.20  14.2000   24.6667
# 52      213             Mpika      ZM     76.77 -11.8343   31.4529
# 53      215      Port Hedland      AU     71.65 -20.3167  118.5667
# 54      221            Harper      LR     79.75   4.3750   -7.7169
# 55      222             Galle      LK     77.34   6.0367   80.2170
# 56      223      Saint-Joseph      RE     71.98 -21.3667   55.6167
# 57      227           Ambanja      MG     75.04 -13.6833   48.4500
# 58      235         Amboasary      MG     73.76 -25.0333   46.3833
# 59      239        Port Blair      IN     77.04  11.6667   92.7500
#
#                                            Hotel Name
# 0                                Grage Hotel Bengkulu
# 1                                         Villa Enata
# 2                      Hotel Atoll Emerald Miyakojima
# 3                                           DoubleFAG
# 4                                      Casa Tia Villa
# 5                                 Pousada Porto Praia
# 6                                   Nuevo Hotel Plaza
# 7                                     People ThankYou
# 8                           Finch Bay Galapagos Hotel
# 9                       Courtyard by Marriott Danbury
# 10                                     Le four à pain
# 11                                  Hotel Nusantara I
# 12                                Methoni Beach Hotel
# 13                                     CHACARA BAILLY
# 14                                Vasidtee City Hotel
# 15                                   Mess keban agung
# 16                         Expeditions Ténére voyages
# 17                                     La Casa Grande
# 18             Hotel htop Calella Palace Family & SPA
# 19                 Bora-Bora Pearl Beach Resort & Spa
# 20                            In Wewak Boutique Hotel
# 21                          International Lodge Motel
# 22                                      Damview Hotel
# 23                                   Residence N'Keni
# 24                             Hotel Star inn Peniche
# 25                                     Cititel Penang
# 26                                Heritage Park Hotel
# 27                                            mtakuja
# 28                                     Mercure Padang
# 29                        Shanti Maurice Resort & Spa
# 30                Sheraton Kauai Coconut Beach Resort
# 31                       Casa Laguna, Bed & Breakfast
# 32  Hotel Grand Continental Kuala Terengganu (4 Star)
# 33                                      La Ode Husein
# 34                                        Akkol Apart
# 35                                  Lords Inn Somnath
# 36                                     Hotel do Campo
# 37                                       Mini Central
# 38                               Swiss-Belhotel Ambon
# 39                                      Hotel Castelo
# 40                                     Penginapan Kim
# 41                                    SEGAYA PROPERTY
# 42                                  The Regency Hotel
# 43                 Shandrani Beachcomber Resort & Spa
# 44                                        Tanna Lodge
# 45                                             Turaif
# 46                                  RH HOTEL (4 Star)
# 47                                 Leumerus Bungalows
# 48                                      Hotel Xaguate
# 49                                    Antonio's Hotel
# 50             Red Crescent Cyclone Shelter Rashulpur
# 51                                Dibbo areaمنطقة دبو
# 52                                     Melodies Lodge
# 53                                The Esplanade Hotel
# 54                                        Screensaver
# 55                                          Amangalla
# 56                      "Plantation Bed and Breakfast
# 57                         Hotel Salama and Fast Food
# 58                                  Le Bon Samaritain
# 59  Welcomhotel By ITC Hotels, Bay Island, Port Blair

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} Ã‚Â°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]=="Bengkulu"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Bengkulu"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Katobu"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Ambon"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Biak"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], \
        vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], \
      vacation_start["Lng"].to_numpy()[0]

# %%
stop1 = vacation_stop1["Lat"].to_numpy()[0], \
        vacation_stop1["Lng"].to_numpy()[0]

# %%
stop2 = vacation_stop2["Lat"].to_numpy()[0], \
        vacation_stop2["Lng"].to_numpy()[0]

# %%
stop3 = vacation_stop3["Lat"].to_numpy()[0], \
        vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary1 = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode = 'DRIVING')

fig.add_layer(city_itinerary1)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
city_itinerary2 = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode = 'BICYCLING')

fig.add_layer(city_itinerary2)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig = gmaps.figure()
city_itinerary3 = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode = 'WALKING')

fig.add_layer(city_itinerary3)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID      City Country  Max Temp     Lat       Lng            Hotel Name
# 0        2  Bengkulu      ID     74.41 -3.8004  102.2655  Grage Hotel Bengkulu
# 1      137    Katobu      ID     75.90 -4.9408  122.5276         La Ode Husein
# 2      144     Ambon      ID     77.14 -3.6954  128.1814  Swiss-Belhotel Ambon
# 3      161      Biak      ID     76.80 -0.9131  122.8766        Penginapan Kim

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} Ã‚Â°F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
city_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=city_info)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
