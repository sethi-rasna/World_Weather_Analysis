# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 1 | taoudenni
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | hirara
# Processing Record 10 of Set 1 | holsted
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | the pas
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | labuhan
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | namwala
# Processing Record 24 of Set 1 | dubna
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | adrar
# Processing Record 27 of Set 1 | goderich
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | panguna
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | praia da vitoria
# Processing Record 33 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | pacific grove
# Processing Record 36 of Set 1 | aksu
# Processing Record 37 of Set 1 | vila franca do campo
# Processing Record 38 of Set 1 | beringovskiy
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | sur
# Processing Record 44 of Set 1 | lata
# Processing Record 45 of Set 1 | la orilla
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | coromandel
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | nabire
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | bubaque
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | uray
# Processing Record 6 of Set 2 | plettenberg bay
# Processing Record 7 of Set 2 | methoni
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | cabo san lucas
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | acarau
# Processing Record 15 of Set 2 | suphan buri
# Processing Record 16 of Set 2 | payo
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | prince rupert
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | pisco
# Processing Record 21 of Set 2 | hofn
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | clyde river
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | sabang
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | bilma
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | whitehorse
# Processing Record 33 of Set 2 | baena
# Processing Record 34 of Set 2 | male
# Processing Record 35 of Set 2 | cruzeiro do sul
# Processing Record 36 of Set 2 | calella
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | erdenet
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | wewak
# Processing Record 41 of Set 2 | ahipara
# Processing Record 42 of Set 2 | mweka
# Processing Record 43 of Set 2 | toora-khem
# Processing Record 44 of Set 2 | mackay
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | beidao
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | chitungwiza
# Processing Record 1 of Set 3 | gamboma
# Processing Record 2 of Set 3 | fria
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | sindor
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | mayo
# Processing Record 7 of Set 3 | missoula
# Processing Record 8 of Set 3 | pontal do parana
# Processing Record 9 of Set 3 | hualmay
# Processing Record 10 of Set 3 | alanya
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | staryy nadym
# Processing Record 14 of Set 3 | henties bay
# Processing Record 15 of Set 3 | mezen
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | peniche
# Processing Record 18 of Set 3 | dongsheng
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | honiara
# Processing Record 21 of Set 3 | songea
# Processing Record 22 of Set 3 | buraydah
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | merauke
# Processing Record 25 of Set 3 | padang
# Processing Record 26 of Set 3 | price
# Processing Record 27 of Set 3 | shimoda
# Processing Record 28 of Set 3 | itarema
# Processing Record 29 of Set 3 | severo-kurilsk
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | kerman
# Processing Record 33 of Set 3 | husavik
# Processing Record 34 of Set 3 | kapaa
# Processing Record 35 of Set 3 | tlahualilo
# City not found. Skipping...
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | salinopolis
# Processing Record 38 of Set 3 | asau
# Processing Record 39 of Set 3 | umm kaddadah
# Processing Record 40 of Set 3 | keti bandar
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 3 | sulangan
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | kuala terengganu
# Processing Record 47 of Set 3 | katobu
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | kumluca
# Processing Record 50 of Set 3 | anloga
# Processing Record 1 of Set 4 | veraval
# Processing Record 2 of Set 4 | ponta do sol
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | ambon
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | sembe
# Processing Record 7 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | orbetello
# Processing Record 10 of Set 4 | udachnyy
# Processing Record 11 of Set 4 | mbarara
# Processing Record 12 of Set 4 | batagay-alyta
# Processing Record 13 of Set 4 | las lomas
# Processing Record 14 of Set 4 | springbok
# Processing Record 15 of Set 4 | conchas
# Processing Record 16 of Set 4 | cidreira
# Processing Record 17 of Set 4 | hovd
# Processing Record 18 of Set 4 | grande prairie
# Processing Record 19 of Set 4 | gao
# Processing Record 20 of Set 4 | milkovo
# Processing Record 21 of Set 4 | dali
# Processing Record 22 of Set 4 | biak
# Processing Record 23 of Set 4 | dingle
# Processing Record 24 of Set 4 | yanam
# Processing Record 25 of Set 4 | maloy
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | sorland
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | sitka
# Processing Record 31 of Set 4 | kavieng
# Processing Record 32 of Set 4 | staunton
# Processing Record 33 of Set 4 | boulsa
# Processing Record 34 of Set 4 | tessalit
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | turayf
# Processing Record 37 of Set 4 | sibu
# Processing Record 38 of Set 4 | havre-saint-pierre
# Processing Record 39 of Set 4 | hella
# Processing Record 40 of Set 4 | hasaki
# Processing Record 41 of Set 4 | friedberg
# Processing Record 42 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | grindavik
# Processing Record 45 of Set 4 | arkhangelos
# City not found. Skipping...
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | bogovarovo
# Processing Record 49 of Set 4 | sola
# Processing Record 50 of Set 4 | saskylakh
# Processing Record 1 of Set 5 | dauphin
# Processing Record 2 of Set 5 | olovyannaya
# Processing Record 3 of Set 5 | margate
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | werda
# Processing Record 6 of Set 5 | yumbe
# Processing Record 7 of Set 5 | sarankhola
# Processing Record 8 of Set 5 | chara
# Processing Record 9 of Set 5 | kutum
# Processing Record 10 of Set 5 | pahrump
# Processing Record 11 of Set 5 | anchorage
# Processing Record 12 of Set 5 | yar-sale
# Processing Record 13 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | diffa
# Processing Record 17 of Set 5 | vostok
# Processing Record 18 of Set 5 | mariental
# Processing Record 19 of Set 5 | oyama
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | petawawa
# Processing Record 22 of Set 5 | riachao das neves
# Processing Record 23 of Set 5 | nahan
# Processing Record 24 of Set 5 | winslow
# Processing Record 25 of Set 5 | jacmel
# Processing Record 26 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 5 | camacha
# Processing Record 28 of Set 5 | smithers
# Processing Record 29 of Set 5 | divnogorsk
# Processing Record 30 of Set 5 | mpika
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | lebu
# Processing Record 33 of Set 5 | port hedland
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | reconquista
# Processing Record 37 of Set 5 | laguna
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | harper
# Processing Record 40 of Set 5 | galle
# Processing Record 41 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 5 | saint-joseph
# Processing Record 43 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 5 | alta floresta
# Processing Record 45 of Set 5 | tura
# Processing Record 46 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 5 | ambanja
# Processing Record 48 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 5 | longyearbyen
# Processing Record 50 of Set 5 | scarborough
# Processing Record 1 of Set 6 | monrovia
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | dubbo
# Processing Record 4 of Set 6 | kununurra
# Processing Record 5 of Set 6 | chisinau
# Processing Record 6 of Set 6 | amboasary
# Processing Record 7 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 6 | san borja
# Processing Record 9 of Set 6 | jimma
# Processing Record 10 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 11 of Set 6 | voznesenye
# Processing Record 12 of Set 6 | port blair
# Processing Record 13 of Set 6 | qaqortoq
# Processing Record 14 of Set 6 | debre birhan
# Processing Record 15 of Set 6 | kingsburg
# Processing Record 16 of Set 6 | banda aceh
# Processing Record 17 of Set 6 | oxelosund
# Processing Record 18 of Set 6 | corrente
# Processing Record 19 of Set 6 | arlit
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | ketchikan
# Processing Record 22 of Set 6 | lingao
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | kilimatinde
# Processing Record 25 of Set 6 | khani
# Processing Record 26 of Set 6 | chadiza
# Processing Record 27 of Set 6 | ialibu
# Processing Record 28 of Set 6 | tubuala
# Processing Record 29 of Set 6 | lannion
# Processing Record 30 of Set 6 | oranjemund
# Processing Record 31 of Set 6 | chiang klang
# Processing Record 32 of Set 6 | paramonga
# Processing Record 33 of Set 6 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 34 of Set 6 | mundo nuevo
# Processing Record 35 of Set 6 | yulara
# Processing Record 36 of Set 6 | ocos
# Processing Record 37 of Set 6 | ibanda
# Processing Record 38 of Set 6 | faya
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | uarini
# Processing Record 41 of Set 6 | kaihua
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 6 | luderitz
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | batagay
# Processing Record 47 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | manono
# Processing Record 1 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 7 | adre
# Processing Record 3 of Set 7 | maningrida
# Processing Record 4 of Set 7 | verkhoyansk
# Processing Record 5 of Set 7 | humaita
# Processing Record 6 of Set 7 | hilo
# Processing Record 7 of Set 7 | chumikan
# Processing Record 8 of Set 7 | opuwo
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | pontes e lacerda
# Processing Record 11 of Set 7 | progreso
# Processing Record 12 of Set 7 | sehithwa
# Processing Record 13 of Set 7 | singaparna
# Processing Record 14 of Set 7 | airai
# Processing Record 15 of Set 7 | paka
# Processing Record 16 of Set 7 | waitati
# Processing Record 17 of Set 7 | mitsamiouli
# Processing Record 18 of Set 7 | slave lake
# Processing Record 19 of Set 7 | marienburg
# Processing Record 20 of Set 7 | tianpeng
# Processing Record 21 of Set 7 | manggar
# Processing Record 22 of Set 7 | anadyr
# Processing Record 23 of Set 7 | popondetta
# Processing Record 24 of Set 7 | puerto baquerizo moreno
# Processing Record 25 of Set 7 | zarubino
# Processing Record 26 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 7 | kankavli
# City not found. Skipping...
# Processing Record 28 of Set 7 | bintulu
# Processing Record 29 of Set 7 | pundaguitan
# Processing Record 30 of Set 7 | berlevag
# Processing Record 31 of Set 7 | masuda
# Processing Record 32 of Set 7 | mehamn
# Processing Record 33 of Set 7 | acari
# Processing Record 34 of Set 7 | olinda
# Processing Record 35 of Set 7 | north bend
# Processing Record 36 of Set 7 | namibe
# Processing Record 37 of Set 7 | malakal
# Processing Record 38 of Set 7 | leh
# Processing Record 39 of Set 7 | adelaide
# Processing Record 40 of Set 7 | monroe
# Processing Record 41 of Set 7 | barra da estiva
# Processing Record 42 of Set 7 | nelson bay
# Processing Record 43 of Set 7 | lincoln
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | talcahuano
# Processing Record 46 of Set 7 | otane
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | xuddur
# Processing Record 49 of Set 7 | bandarbeyla
# Processing Record 50 of Set 7 | gornozavodsk
# Processing Record 1 of Set 8 | thunder bay
# Processing Record 2 of Set 8 | touros
# Processing Record 3 of Set 8 | tahta
# Processing Record 4 of Set 8 | san rafael
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | pinhao
# Processing Record 7 of Set 8 | luwuk
# Processing Record 8 of Set 8 | asilah
# Processing Record 9 of Set 8 | eureka
# Processing Record 10 of Set 8 | erenhot
# Processing Record 11 of Set 8 | yoichi
# Processing Record 12 of Set 8 | andenes
# Processing Record 13 of Set 8 | sinnamary
# Processing Record 14 of Set 8 | juan lacaze
# Processing Record 15 of Set 8 | yagodnoye
# Processing Record 16 of Set 8 | poum
# Processing Record 17 of Set 8 | namatanai
# Processing Record 18 of Set 8 | nuuk
# Processing Record 19 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 8 | katherine
# Processing Record 21 of Set 8 | changji
# Processing Record 22 of Set 8 | atar
# Processing Record 23 of Set 8 | sibolga
# Processing Record 24 of Set 8 | port macquarie
# Processing Record 25 of Set 8 | ulladulla
# Processing Record 26 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 8 | prince albert
# Processing Record 28 of Set 8 | zambezi
# Processing Record 29 of Set 8 | pampa
# Processing Record 30 of Set 8 | kasrawad
# Processing Record 31 of Set 8 | mahibadhoo
# Processing Record 32 of Set 8 | barranca
# Processing Record 33 of Set 8 | mizdah
# Processing Record 34 of Set 8 | yingcheng
# Processing Record 35 of Set 8 | torzhok
# Processing Record 36 of Set 8 | tete
# Processing Record 37 of Set 8 | mount isa
# Processing Record 38 of Set 8 | mizan teferi
# Processing Record 39 of Set 8 | kurtamysh
# Processing Record 40 of Set 8 | kalmunai
# Processing Record 41 of Set 8 | anori
# Processing Record 42 of Set 8 | sechelt
# Processing Record 43 of Set 8 | koungheul
# Processing Record 44 of Set 8 | sioux lookout
# Processing Record 45 of Set 8 | kalianget
# Processing Record 46 of Set 8 | necochea
# Processing Record 47 of Set 8 | bay roberts
# Processing Record 48 of Set 8 | lavrentiya
# Processing Record 49 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 8 | correntina
# Processing Record 1 of Set 9 | broken hill
# Processing Record 2 of Set 9 | cienfuegos
# Processing Record 3 of Set 9 | pogaceaua
# Processing Record 4 of Set 9 | cefalu
# Processing Record 5 of Set 9 | mayskiy
# Processing Record 6 of Set 9 | plouzane
# Processing Record 7 of Set 9 | sabha
# Processing Record 8 of Set 9 | aklavik
# Processing Record 9 of Set 9 | rock sound
# Processing Record 10 of Set 9 | taunggyi
# Processing Record 11 of Set 9 | tahe
# Processing Record 12 of Set 9 | kijang
# Processing Record 13 of Set 9 | jumla
# Processing Record 14 of Set 9 | constitucion
# Processing Record 15 of Set 9 | barcelos
# Processing Record 16 of Set 9 | port lincoln
# Processing Record 17 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 9 | labytnangi
# Processing Record 19 of Set 9 | burgeo
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | chapais
# Processing Record 23 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 24 of Set 9 | mersing
# Processing Record 25 of Set 9 | roma
# Processing Record 26 of Set 9 | rio gallegos
# Processing Record 27 of Set 9 | pangody
# Processing Record 28 of Set 9 | kurilsk
# Processing Record 29 of Set 9 | mocuba
# Processing Record 30 of Set 9 | moose factory
# Processing Record 31 of Set 9 | zilair
# Processing Record 32 of Set 9 | iqaluit
# Processing Record 33 of Set 9 | zhigansk
# Processing Record 34 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 9 | coquimbo
# Processing Record 36 of Set 9 | yeppoon
# Processing Record 37 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 9 | sokoni
# Processing Record 39 of Set 9 | dhidhdhoo
# Processing Record 40 of Set 9 | winthrop
# Processing Record 41 of Set 9 | balatonfured
# Processing Record 42 of Set 9 | dongfeng
# Processing Record 43 of Set 9 | rockhampton
# Processing Record 44 of Set 9 | san pedro
# Processing Record 45 of Set 9 | dindigul
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | tecoanapa
# Processing Record 48 of Set 9 | seymchan
# Processing Record 49 of Set 9 | port-cartier
# Processing Record 50 of Set 9 | karratha
# Processing Record 1 of Set 10 | oussouye
# Processing Record 2 of Set 10 | gornopravdinsk
# Processing Record 3 of Set 10 | atherton
# Processing Record 4 of Set 10 | bardiyah
# Processing Record 5 of Set 10 | caravelas
# Processing Record 6 of Set 10 | clacton-on-sea
# Processing Record 7 of Set 10 | dombarovskiy
# Processing Record 8 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 10 | fortuna
# Processing Record 11 of Set 10 | bam
# Processing Record 12 of Set 10 | kashi
# Processing Record 13 of Set 10 | iranshahr
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | karpathos
# Processing Record 16 of Set 10 | pag
# Processing Record 17 of Set 10 | rocha
# City not found. Skipping...
# Processing Record 18 of Set 10 | ust-omchug
# Processing Record 19 of Set 10 | esmeraldas
# Processing Record 20 of Set 10 | kathu
# Processing Record 21 of Set 10 | luanda
# Processing Record 22 of Set 10 | paita
# Processing Record 23 of Set 10 | xichang
# Processing Record 24 of Set 10 | pudozh
# Processing Record 25 of Set 10 | along
# Processing Record 26 of Set 10 | viedma
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | raozan
# City not found. Skipping...
# Processing Record 29 of Set 10 | huarmey
# Processing Record 30 of Set 10 | wad madani
# Processing Record 31 of Set 10 | coxim
# Processing Record 32 of Set 10 | gwadar
# Processing Record 33 of Set 10 | coihaique
# Processing Record 34 of Set 10 | beyneu
# Processing Record 35 of Set 10 | roald
# Processing Record 36 of Set 10 | alice springs
# Processing Record 37 of Set 10 | aitape
# Processing Record 38 of Set 10 | zyryanka
# Processing Record 39 of Set 10 | san quintin
# Processing Record 40 of Set 10 | reyes
# Processing Record 41 of Set 10 | felanitx
# Processing Record 42 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 44 of Set 10 | santa maria
# Processing Record 45 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 10 | mamit
# Processing Record 47 of Set 10 | bambanglipuro
# Processing Record 48 of Set 10 | emba
# Processing Record 49 of Set 10 | kaitangata
# Processing Record 50 of Set 10 | bilibino
# Processing Record 1 of Set 11 | san cristobal
# Processing Record 2 of Set 11 | umm lajj
# Processing Record 3 of Set 11 | vallenar
# Processing Record 4 of Set 11 | vilaka
# Processing Record 5 of Set 11 | santiago de cao
# Processing Record 6 of Set 11 | makurdi
# Processing Record 7 of Set 11 | quatre cocos
# Processing Record 8 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 11 | wanning
# Processing Record 10 of Set 11 | gazojak
# Processing Record 11 of Set 11 | ostrovnoy
# Processing Record 12 of Set 11 | santa vitoria do palmar
# Processing Record 13 of Set 11 | boshnyakovo
# Processing Record 14 of Set 11 | angangxi
# City not found. Skipping...
# Processing Record 15 of Set 11 | palana
# Processing Record 16 of Set 11 | jinchang
# Processing Record 17 of Set 11 | methven
# Processing Record 18 of Set 11 | baranchinskiy
# Processing Record 19 of Set 11 | mutsu
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | vuktyl
# Processing Record 22 of Set 11 | belyy yar
# Processing Record 23 of Set 11 | alugan
# Processing Record 24 of Set 11 | loukhi
# Processing Record 25 of Set 11 | saryozek
# Processing Record 26 of Set 11 | diamantino
# Processing Record 27 of Set 11 | kailua
# Processing Record 28 of Set 11 | pombia
# Processing Record 29 of Set 11 | fuzhou
# Processing Record 30 of Set 11 | abu dhabi
# Processing Record 31 of Set 11 | cockburn town
# Processing Record 32 of Set 11 | elko
# Processing Record 33 of Set 11 | georgiyevskoye
# Processing Record 34 of Set 11 | angoche
# Processing Record 35 of Set 11 | marzuq
# Processing Record 36 of Set 11 | morehead
# Processing Record 37 of Set 11 | athabasca
# Processing Record 38 of Set 11 | merthyr tydfil
# Processing Record 39 of Set 11 | xining
# Processing Record 40 of Set 11 | inhambane
# Processing Record 41 of Set 11 | yerkoy
# Processing Record 42 of Set 11 | regina
# Processing Record 43 of Set 11 | palimbang
# Processing Record 44 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 11 | sisimiut
# Processing Record 46 of Set 11 | galeana
# Processing Record 47 of Set 11 | baherden
# Processing Record 48 of Set 11 | pastavy
# Processing Record 49 of Set 11 | pangnirtung
# Processing Record 50 of Set 11 | amapa
# Processing Record 1 of Set 12 | tevaitoa
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | ahvaz
# Processing Record 4 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 12 | gat
# Processing Record 7 of Set 12 | ijui
# Processing Record 8 of Set 12 | bathsheba
# Processing Record 9 of Set 12 | santiago del estero
# Processing Record 10 of Set 12 | sangar
# Processing Record 11 of Set 12 | novyy urengoy
# Processing Record 12 of Set 12 | aripuana
# Processing Record 13 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 12 | gomez palacio
# Processing Record 15 of Set 12 | shar
# Processing Record 16 of Set 12 | karachi
# Processing Record 17 of Set 12 | santa cruz
# Processing Record 18 of Set 12 | kiama
# Processing Record 19 of Set 12 | kjopsvik
# Processing Record 20 of Set 12 | neuquen
# Processing Record 21 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 12 | olafsvik
# Processing Record 23 of Set 12 | bonavista
# Processing Record 24 of Set 12 | armacao de pera
# Processing Record 25 of Set 12 | gasa
# Processing Record 26 of Set 12 | port moresby
# Processing Record 27 of Set 12 | pergamino
# Processing Record 28 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 12 | prainha
# Processing Record 30 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 12 | dandong
# Processing Record 32 of Set 12 | abu kamal
# Processing Record 33 of Set 12 | imperatriz
# Processing Record 34 of Set 12 | carutapera
# Processing Record 35 of Set 12 | crotone
# Processing Record 36 of Set 12 | palencia
# Processing Record 37 of Set 12 | hay river
# Processing Record 38 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | kupang
# Processing Record 40 of Set 12 | port hawkesbury
# Processing Record 41 of Set 12 | borama
# City not found. Skipping...
# Processing Record 42 of Set 12 | rio cuarto
# Processing Record 43 of Set 12 | cordoba
# Processing Record 44 of Set 12 | oktyabrskoye
# Processing Record 45 of Set 12 | susanville
# Processing Record 46 of Set 12 | half moon bay
# Processing Record 47 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 48 of Set 12 | moustheni
# Processing Record 49 of Set 12 | odweyne
# Processing Record 50 of Set 12 | kalabugao
# City not found. Skipping...
# Processing Record 1 of Set 13 | samarai
# Processing Record 2 of Set 13 | chokurdakh
# Processing Record 3 of Set 13 | olpad
# Processing Record 4 of Set 13 | astoria
# Processing Record 5 of Set 13 | the valley
# Processing Record 6 of Set 13 | portsmouth
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | port-de-bouc
# Processing Record 9 of Set 13 | kansanshi
# Processing Record 10 of Set 13 | kirkwood
# Processing Record 11 of Set 13 | mongoumba
# Processing Record 12 of Set 13 | quchan
# Processing Record 13 of Set 13 | la rioja
# Processing Record 14 of Set 13 | rennes
# Processing Record 15 of Set 13 | aswan
# Processing Record 16 of Set 13 | gweta
# Processing Record 17 of Set 13 | kwinana
# Processing Record 18 of Set 13 | rawlins
# Processing Record 19 of Set 13 | rio branco
# Processing Record 20 of Set 13 | srednekolymsk
# Processing Record 21 of Set 13 | brae
# Processing Record 22 of Set 13 | northam
# Processing Record 23 of Set 13 | teguise
# Processing Record 24 of Set 13 | lasem
# Processing Record 25 of Set 13 | seydisehir
# Processing Record 26 of Set 13 | kushima
# Processing Record 27 of Set 13 | kulhudhuffushi
# Processing Record 28 of Set 13 | shingu
# Processing Record 29 of Set 13 | turukhansk
# Processing Record 30 of Set 13 | bijie
# Processing Record 31 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 13 | noumea
# Processing Record 33 of Set 13 | aketi
# Processing Record 34 of Set 13 | kefamenanu
# Processing Record 35 of Set 13 | howard springs
# Processing Record 36 of Set 13 | sumbe
# Processing Record 37 of Set 13 | arrecife
# Processing Record 38 of Set 13 | esperance
# Processing Record 39 of Set 13 | ovalle
# Processing Record 40 of Set 13 | arona
# Processing Record 41 of Set 13 | ye
# City not found. Skipping...
# Processing Record 42 of Set 13 | kulunda
# Processing Record 43 of Set 13 | maridi
# Processing Record 44 of Set 13 | balkanabat
# Processing Record 45 of Set 13 | zhengjiatun
# Processing Record 46 of Set 13 | lasa
# Processing Record 47 of Set 13 | kismayo
# Processing Record 48 of Set 13 | ayagoz
# Processing Record 49 of Set 13 | may pen
# Processing Record 50 of Set 13 | monte alegre
# Processing Record 1 of Set 14 | badvel
# Processing Record 2 of Set 14 | longyan
# Processing Record 3 of Set 14 | cabuyaro
# Processing Record 4 of Set 14 | lakatoro
# Processing Record 5 of Set 14 | rostovka
# Processing Record 6 of Set 14 | celestun
# Processing Record 7 of Set 14 | isla mujeres
# Processing Record 8 of Set 14 | helong
# Processing Record 9 of Set 14 | bacolod
# Processing Record 10 of Set 14 | balabac
# Processing Record 11 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 14 | sanmenxia
# Processing Record 13 of Set 14 | montemarciano
# Processing Record 14 of Set 14 | selma
# Processing Record 15 of Set 14 | skibbereen
# Processing Record 16 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 17 of Set 14 | sinop
# Processing Record 18 of Set 14 | mabaruma
# Processing Record 19 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 20 of Set 14 | raasiku
# Processing Record 21 of Set 14 | austin
# Processing Record 22 of Set 14 | ishigaki
# Processing Record 23 of Set 14 | kangaatsiaq
# Processing Record 24 of Set 14 | tazovskiy
# Processing Record 25 of Set 14 | lucapa
# Processing Record 26 of Set 14 | birao
# Processing Record 27 of Set 14 | usakos
# Processing Record 28 of Set 14 | corinth
# Processing Record 29 of Set 14 | svetlogorsk
# Processing Record 30 of Set 14 | oriximina
# Processing Record 31 of Set 14 | grand gaube
# Processing Record 32 of Set 14 | vanimo
# Processing Record 33 of Set 14 | khakhea
# Processing Record 34 of Set 14 | soligalich
# Processing Record 35 of Set 14 | chipata
# Processing Record 36 of Set 14 | waddan
# Processing Record 37 of Set 14 | hami
# Processing Record 38 of Set 14 | manakara
# Processing Record 39 of Set 14 | port-gentil
# Processing Record 40 of Set 14 | kichera
# Processing Record 41 of Set 14 | kisangani
# Processing Record 42 of Set 14 | wonthaggi
# Processing Record 43 of Set 14 | petatlan
# Processing Record 44 of Set 14 | deniliquin
# Processing Record 45 of Set 14 | kungurtug
# Processing Record 46 of Set 14 | ucluelet
# Processing Record 47 of Set 14 | mogadishu
# Processing Record 48 of Set 14 | acapulco
# Processing Record 49 of Set 14 | ngunguru
# Processing Record 50 of Set 14 | yatou
# Processing Record 1 of Set 15 | marmaron
# City not found. Skipping...
# Processing Record 2 of Set 15 | kahului
# Processing Record 3 of Set 15 | talara
# Processing Record 4 of Set 15 | tyrma
# Processing Record 5 of Set 15 | kars
# Processing Record 6 of Set 15 | kollam
# Processing Record 7 of Set 15 | chernenko
# Processing Record 8 of Set 15 | abnub
# Processing Record 9 of Set 15 | do gonbadan
# Processing Record 10 of Set 15 | lac du bonnet
# Processing Record 11 of Set 15 | balykshi
# Processing Record 12 of Set 15 | oranjestad
# Processing Record 13 of Set 15 | dunedin
# Processing Record 14 of Set 15 | shache
# Processing Record 15 of Set 15 | krasnotorka
# Processing Record 16 of Set 15 | baykit
# Processing Record 17 of Set 15 | shahrud
# Processing Record 18 of Set 15 | tabuk
# Processing Record 19 of Set 15 | kenai
# Processing Record 20 of Set 15 | leshukonskoye
# Processing Record 21 of Set 15 | vardo
# Processing Record 22 of Set 15 | egvekinot
# Processing Record 23 of Set 15 | pampierstad
# Processing Record 24 of Set 15 | puerto carreno
# Processing Record 25 of Set 15 | batticaloa
# Processing Record 26 of Set 15 | ambulu
# Processing Record 27 of Set 15 | sapa
# Processing Record 28 of Set 15 | tallahassee
# Processing Record 29 of Set 15 | chino
# Processing Record 30 of Set 15 | chibombo
# Processing Record 31 of Set 15 | fort morgan
# Processing Record 32 of Set 15 | pasni
# Processing Record 33 of Set 15 | ban nahin
# Processing Record 34 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 15 | tamale
# Processing Record 36 of Set 15 | mayumba
# Processing Record 37 of Set 15 | kuytun
# Processing Record 38 of Set 15 | kendari
# Processing Record 39 of Set 15 | marshfield
# Processing Record 40 of Set 15 | aksehir
# Processing Record 41 of Set 15 | nouakchott
# Processing Record 42 of Set 15 | qom
# Processing Record 43 of Set 15 | mongo
# Processing Record 44 of Set 15 | mercedes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff      NZ -46.6000  168.3333     47.80        88         100
# 1         Tiksi      RU  71.6872  128.8694      0.63        99          68
# 2      Bengkulu      ID  -3.8004  102.2655     74.41        91         100
# 3        Atuona      PF  -9.8000 -139.0333     77.13        72          15
# 4     Taoudenni      ML  22.6783   -3.9836     88.90        10          57
# ..          ...     ...      ...       ...       ...       ...         ...
# 677     Aksehir      TR  38.3575   31.4164     55.63        39           3
# 678  Nouakchott      MR  18.0858  -15.9785     85.93        61          24
# 679         Qom      IR  34.6401   50.8764     66.65        34           2
# 680       Mongo      TD  12.1844   18.6930     84.36        23          12
# 681    Mercedes      AR -34.6515  -59.4307     78.94        42          63
#
#      Wind Speed                 Date
# 0         10.71  2022-10-26 17:44:00
# 1          6.40  2022-10-26 17:44:42
# 2          4.41  2022-10-26 17:44:43
# 3         18.68  2022-10-26 17:44:43
# 4          9.22  2022-10-26 17:44:44
# ..          ...                  ...
# 677        2.84  2022-10-26 18:14:30
# 678       16.04  2022-10-26 18:14:22
# 679        3.38  2022-10-26 18:14:34
# 680        2.68  2022-10-26 18:14:35
# 681       21.59  2022-10-26 18:14:37
#
# [682 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
